# %%
#!pip install -r requirements.txt

# %% [markdown]
# # Create Connection (Mandatory Run) and Show Data screenshot
# ### Establish a Girger Connection with IMQ Database and show the data

# %%
from forms_lib import forms
import pandas as pd
from girder_client import GirderClient

client = GirderClient(apiUrl="https://data.imqcam.org/api/v1")
client.authenticate(apiKey='ZWsKLbWmokMjJeE6Ihz7Zve74rZWiJLHyAALBNGB')

fm = forms(client)
fm.show_data()
# Out:
#    Build_Date                                     Build_ID  DOE_Code DOE_ID  \
# 0  2022-01-01  A01_2022-01-01_JHUAPL_EOSM290_Ti64_Cylinder         1      A
# 1  2022-01-01  A02_2022-01-01_JHUAPL_EOSM290_Ti64_Cylinder         1      A
# 2  2022-01-01  A03_2022-01-01_JHUAPL_EOSM290_Ti64_Cylinder         1      A
# 3  2022-01-01  A04_2022-01-01_JHUAPL_EOSM290_Ti64_Cylinder         1      A
# 4  2022-01-01  A05_2022-01-01_JHUAPL_EOSM290_Ti64_Cylinder         1      A
#
#    Elongation_Percent  Hatch_mm  Layer_mm  Modulus_GPa Orientation  \
# 0            7.329018      0.14      0.03     82.95913  Horizontal
# 1            6.279538      0.14      0.03     83.17367  Horizontal
# 2           12.403910      0.14      0.03    100.26750  Horizontal
# 3            8.149077      0.14      0.03     93.70417  Horizontal
# 4           10.102670      0.14      0.03     99.61740  Horizontal
#
#   Parameter_Label  Peak_Stress_MPa  Percent_Porosity_Contour  \
# ...

# %% [markdown]
# # Convex Hull Plot
# ### Creates Scater Plot of Elengation Percent vs Yeild_Stength

# %%
fm.convex_hull()
# Out:
# /Users/akhilaponugoti/Documents/tale_forms/forms_lib.py:86: UserWarning: The palette list has more values (7) than needed (3), which may not be intended.
#   sns.scatterplot(

# %% [markdown]
# # Scatter Plot
# ### Creates Scater Plot of Elengation Percent vs Yeild_Stength

# %%
fm.scatter_plot()
# Out:
# /Users/akhilaponugoti/Documents/tale_forms/forms_lib.py:43: UserWarning: The palette list has more values (7) than needed (3), which may not be intended.
#   sns.scatterplot(
